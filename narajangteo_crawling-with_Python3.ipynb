# %% [markdown]
# # <center> 나라장터 입찰공고 크롤링 with Python3</center>
#
# 나라장터에 올라오는 입찰공고를 모니터링하기 위해 개발된 간단한 프로그램으로, 검색어 리스트를 설정하면 그에 따라 최근 7일간 공고된 입찰공고 리스트를 가져와 엑셀파일로 정리해줍니다. 크롤링 프로그램이지만, BeautifulSoup을 사용하지 않습니다.

# %%
import pandas as pd
import numpy as np
import requests
import os
import datetime, time
import string
from time import localtime, strftime
from datetime import timedelta
from tqdm import tqdm
from xlsxwriter.utility import xl_col_to_name, xl_range

# %%
class KoreaPageScraper(object):
    def __init__(self):
        pass
    
    def request_url(self,cat):
        '''returns url for a  category'''
        d = datetime.date.today()
        fromtd = d - timedelta(days=7)
        start_date = str(fromtd.strftime("%Y/%m/%d"))
        end_date =str(d.strftime("%Y/%m/%d"))
        fromBidDt = requests.utils.quote(start_date, safe='')
        toBidDt = requests.utils.quote(end_date, safe='')
        bidNm = requests.utils.quote(cat.encode('euc-kr'))
        url = "http://www.g2b.go.kr:8101/ep/tbid/tbidList.do?taskClCds=&bidNm=" + bidNm + "&searchDtType=1&fromBidDt=" + fromBidDt + "&toBidDt=" + toBidDt + "&fromOpenBidDt=&toOpenBidDt=&radOrgan=1&instNm=&exceptEnd=Y&area=&regYn=Y&bidSearchType=1&searchType=1&recordCountPerPage=1000"
        return url

    def scrape_cat(self,cat):
        cat_url = self.request_url(cat)
        df = pd.read_html(cat_url)[0]
        df['search_term']=cat
        return df
    
    def get_bidurl(self,bidnum):
        num_split = str(bidnum).split(sep='-')
        bidno = num_split[0]
        if len(bidno) == 11:
            bidseq = num_split[-1]
            bidurl = '''=HYPERLINK("http://www.g2b.go.kr:8081/ep/invitation/publish/bidInfoDtl.do?bidno='''+bidno+'''&bidseq='''+bidseq+'''","Click link")'''
            return bidurl
        else: 
            return "Check organization website (공고기관) for details"
        bidseq = refnum_split[-1]
        bidurl = '''=HYPERLINK("http://www.g2b.go.kr:8081/ep/invitation/publish/bidInfoDtl.do?bidno='''+bidno+'''&bidseq='''+bidseq+'''","Click link")'''
        return bidurl

    def scrape_categories(self, categories):
        #add a slight delay betweeen scrapes: time.sleep(1)
        appended_df = []
        for category in tqdm(categories):
            one_df = self.scrape_cat(category)
            appended_df.append(one_df)
            time.sleep(1)
        appended_df = pd.concat(appended_df, axis = 0)
        urlist=[]
        for index,row in appended_df.iterrows():
            urlist.append(self.get_bidurl(row['공고번호-차수']))
            
        appended_df['url']=urlist
        return appended_df

# %%
def txt_reader(name):
    with open(name+".txt",'rb') as f:
        line = f.readline()
        return line.decode('utf-8').split('/')

# %%
#load the categories
category_list = txt_reader('category')

#scrape!
myscraper = KoreaPageScraper()

df = myscraper.scrape_categories(category_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:17<00:00,  4.79s/it]

# %%
df
# Out:
#      업무         공고번호-차수   분류  \
# 0    물품  20170501700-00   긴급
# 1    물품  20170501487-00   일반
# 2    물품  20170442304-00   일반
# 3    물품  20170442288-00   일반
# 4    물품  20170442297-00   일반
# 5    물품  20170442277-00   일반
# 6    물품  20170501481-00   일반
# 7    물품  20170501675-00   긴급
# 8    물품  20170442236-00   일반
# 9    물품  20170501518-00   일반
# 10   물품  20170500107-00   긴급
# 11   물품  20170501652-00   일반
# 12   물품  20170501643-00   긴급
# 13   물품  20170500067-00   긴급
# 14   물품  20170501642-00   긴급
# 15   물품  20170438895-00   일반
# 16   물품  20170438882-00   일반
# 17   물품  20170501636-00   일반
# 18   물품  20170501597-00   일반
# 19   물품  20170501589-00   일반
# 20   물품  20170501634-00   일반
# 21   물품  20170501057-00   일반
# 22   물품  20170438849-00   일반
# 23   물품  20170442522-00   긴급
# 24   물품  20170501364-00   일반
# 25   물품  20170437489-00   일반
# 26   물품  20170439767-01   변경
# 27   물품  20170501598-00   일반
# 28   물품  20170442530-00   일반
# 29   물품  20170500756-00   일반
# ..   ..             ...  ...
# 970  용역  20170439731-00   일반
# 971  용역  20170438993-02   변경
# 972  용역  20170439914-00   긴급
# 973  용역  20170440349-00   일반
# 974  용역  20170440386-00   일반
# 975  용역  20170440376-00   일반
# 976  용역  20170440193-00   긴급
# 977  용역  20170440278-00  재입찰
# 978  용역  20170440359-00   일반
# 979  용역  20170440353-00   일반
# 980  용역  20170440229-00   긴급
# 981  용역  20170440025-01   변경
# 982  용역  20170440342-00   긴급
# 983  용역  20170440338-00   일반
# 984  용역  20170439227-01   변경
# 985  용역  20170440329-00   일반
# 986  용역  20170440337-00   일반
# 987  용역  20170440334-00   일반
# 988  용역  20170440339-00   일반
# 989  용역  20170440061-00   일반
# 990  용역  20170440314-00   일반
# 991  용역  20170440121-00   일반
# 992  용역  20170440286-00   일반
# 993  용역  20170440320-00   일반
# 994  용역  20170438648-01   변경
# 995  용역  20170440305-00   긴급
# 996  용역   E011705125-00   일반
# 997  용역  20170439977-00   일반
# 998  용역  20170440187-00   긴급
# 999  용역    2017-0234-00   일반
#
#                                                    공고명  \
# 0                        성균관대역 개발사업 관급자재(안내사인물) 구매(긴급)
# 1                            2017년 경제성종자 방류사업(전복) 단가구매
# 2              경북대학교 생태환경대학 실험실습기자재 등(초순수제조장치 외 8종) 구매
# 3               경북대학교 생태환경대학 실험실습기자재 등(무선 근전도 측정세트) 구매
# 4             경북대학교 생태환경대학 실험실습기자재 등(미량원심분리기 외 12종) 구매
# 5                경북대학교 생태환경대학 실험실습기자재 등(토양경도계 외 3종) 구매
# 6                                        총 유기탄소 분석기 구매
# 7                  2017학년도 노화고등학교 교복(하복, 동복) 구매 재입찰 공고
# 8                 경북대학교 생태환경대학 실험실습기자재 등(Ph메타 외 7종) 구매
# 9                 물산업클러스터조성사업 슬러지수집기(수중대차식, 비금속체인식) 구매
# 10                       실험실습기자재(정상분만모형 1종 1점, 의과대학)구매
# 11                                  주택용 소방시설 물품구매(소화기)
# 12           강원대학교 학생생활관(춘천)2017년 6월분 급식물품(농산물)구매 입찰공고
# 13                       실험실습기자재(뇌파분석장치 1종 1점, 사범대학)구매
# 14            실험실습기자재(Co-Sputtering 시스템 1종 1점, 공과대학)구매
# 15                             농소초등학교 이전 신축 방송장비 구매 설치
# 16                        농소초등학교 이전 신축 CCTV설비 제작 구매 설치
# 17                   임자진리권역 종합정비사업 지급자재 대파탈피기 제조·구매 설치
# 18   2017학년도 천곡중학교 3학년 졸업앨범 제작, 구매 2단계(규격, 가격동시) 입찰 공고
# 19                    위례지구 A1-10BL 아파트 건설공사(조경) 경관석 구매
# 20                                     혈액학분석기 구매 입찰 공고
# 21            경상대학교 농업생명과학대학 실험실습기자재 구매(가민위치수신기 등 33종)
# 22                         농소초등학교 이전 신축 통합배선반 제작 구매 설치
# 23                    2017년 농어촌의료서비스개선사업 의료장비(약포장기) 구매
# 24             경상대학교 농업생명과학대학 실험실습기자재 구매(식물뿌리분석기 등 4종)
# 25                             농소초등학교 이전 신축 공기조화기 구매설치
# 26                            개포디지털혁신파크 무대 및 기타조명 구매설치
# 27                 2017년 추성마을 하수도시설 설치공사 자외선 소독기 구매 설치
# 28                                 부안군 자동음성통보시스템 구매 설치
# 29                         주요전염병검진 소모품 1차 구입(물품구매입찰공고)
# ..                                                 ...
# 970                        경기도교육연수원 2017년 원격연수 콘텐츠개발용역
# 971              제주발전연구원 제주학연구센터 제주역사 편찬사업 용역(협상)입찰 공고
# 972  제39회 전국학생과학발명품경진대회 및 제63회 전국과학전람회 출품작품 선행기술 검색 용역
# 973                      2017년 소방시설 종합정밀점검 및 작동기능점검 용역
# 974                            (재공고)국민연금 관리 30년사 편찬 용역
# 975               충남대학교병원 사업장폐기물(일반쓰레기)처리 위탁용역(장기계속계약)
# 976                      광주역세권 개발사업 생태형 공원녹지 조성모델 연구용역
# 977                    관세행정 자체 청렴도 조사 및 전화응대 친절도 점검 용역
# 978           가락초등학교 등 2교(대저초) 스탠드보수 및 기타공사 건설폐기물 처리용역
# 979                 2017년 혁신형 중소기업 인증 지원사업 컨설팅 용역(재공고)
# 980                   진로 탐색,체험 프로그램 위탁운영 용역(협상에 의한 계약)
# 981                    사업수행능력 평가서 제출안내(덕천IC교 정밀안전진단용역)
# 982                              2017 김해가야테마파크 불꽃축제 용역
# 983                      2017학년도 송정서초등학교 6학년 수학여행 위탁용역
# 984                 거제시 음식물류폐기물처리시설 잔재물(건조음식물) 위탁처리 용역
# 985                       자동차검사관리시스템[VIMS] 프로그램 고도화 용역
# 986                              소화조 및 저류조 퇴적물 제거용역-중랑
# 987  2025 아산시 도시경관관리계획(재정비) 수립용역 집행계획 및 사업수행능력평가서 제출안내
# 988                   읍실.신음 농어촌마을 하수도 정비사업 통합건설사업관리 용역
# 989           2017학년도 오정초등학교 6학년 수학여행 위탁용역 수의 견적 제출 공고
# 990              2017학년도 서울신내초등학교 6학년 소규모테마형교육여행 위탁 용역
# 991                     목포고용센터 시설물유지관리서비스(안내 및 일반관리)용역
# 992            용역사업 집행계획 및 사업수행능력평가서 제출 안내공고(항공사진촬영판독)
# 993                                 화천군 행정홈페이지 전면개편 용역
# 994     2017학년도 망포고등학교 1일형 체험학습(백두대간 종주) 일부위탁 용역 입찰 공고
# 995                 영광중앙초 외 5교 우레탄트랙 철거공사 가연성 폐기물 처리용역
# 996                          2017년도 영암지사 배전설비 열화상진단 용역
# 997               경기과학고 2017년 국제교류 위탁용역 소액수의 견적제출 안내공고
# 998                      자기주도 학습 캠프 위탁운영 용역(협상에 의한 계약)
# 999                                   제2여객터미널 탑승교 운영용역
#
#                              공고기관                          수요기관  \
# 0                        코레일유통(주)                      코레일유통(주)
# 1                        경상북도 영덕군                      경상북도 영덕군
# 2                    경북대학교 생태환경대학                  경북대학교 생태환경대학
# 3                    경북대학교 생태환경대학                  경북대학교 생태환경대학
# 4                    경북대학교 생태환경대학                  경북대학교 생태환경대학
용역  =HYPERLINK("http://www.g2b.go.kr:8081/ep/invit...
# 998          용역  =HYPERLINK("http://www.g2b.go.kr:8081/ep/invit...
# 999          용역      Check organization website (공고기관) for details
#
# [2512 rows x 12 columns]

# %%
def clean_up(df):
    #Delete duplicates (more than two keywords together)
    df = df[~df.duplicated(['공고명'])].copy()
    #Divide the register date and due date
    df['register_date'],df['duedate'] = df['입력일시(입찰마감일시)'].str.split('(', 1).str
    df['duedate']=df['duedate'].str.replace(')','').replace('-','')
    df = df.drop('입력일시(입찰마감일시)',axis=1)
    df = df.sort_values(by='duedate',ascending=False)
    return df

# %%
def filter_prioritize(df,filter_list,column):
    new_df = df[df[column].isin(filter_list)].copy()
    new_df[str(column+"_sorted")] = pd.Categorical(new_df[column],categories=filter_list,ordered=True)
    new_df = new_df.sort_values(column+"_sorted")
    return new_df

# %%
class create_excel(object):
    def get_length(self,column):
        ##
        ##This line is the problem!!
        ##
        valueex = column[~column.isnull()].reset_index(drop=True)[0]
        if type(valueex) == str:
            if valueex.startswith('=HYPERLINK'):
                return len('Click link')
            else: 
                len_list = list(column.dropna().apply(lambda x: len(str(x))))
                maxlen = max(len_list)
                medlen = np.median(len_list)
                meanlen = np.mean(len_list)
                diff = maxlen-medlen
                stdlen = np.std(len_list)
                #min(A,B+C*numchars)
                if maxlen < 10:
                    return maxlen+5
                elif diff > 50:
                    if medlen == 0:
                        return min(55,meanlen+5)
                    return medlen
                elif maxlen < 50:
                    return meanlen+15
                else:
                    return 50
        else:
            return 5

    def to_excel(self,df,name):
        #Next step, format the excel file
        print("saving the "+name+" list...")
        docname = "나라장터_입찰공고-"+name+"-"+str(strftime("%y%m%d(%H%M%S)", localtime()))+".xlsx"
        #make the destination directory, but guard against race condition
        if not os.path.exists(name):
            try:
                os.makedirs(name)
            except OSError as exc: 
                print(exc)
                raise Exception('something failed')
        writer = pd.ExcelWriter("%s/%s"%(name,docname), engine='xlsxwriter')
        df.to_excel(writer,index=False,sheet_name='Sheet1')
        workbook  = writer.book
        worksheet = writer.sheets['Sheet1']
        tablerange = xl_range(0,0,len(df),len(df.columns)-1)
        headerrange = xl_range(0,0,0,len(df.columns)-1)
        contentrange = xl_range(1,0,len(df),len(df.columns)-1)

        #Formatting headers
        header_format = workbook.add_format({'bg_color':'black'})
        column_format = workbook.add_format({'bottom':True,'bg_color':'white'})
        link_format = workbook.add_format({'font_color':'#157993','underline':True})
        
        # Set the column width and format.
        columns = []
        widths = []
        for i in range(0,len(df.columns)):
            a = xl_col_to_name(i)+":"+xl_col_to_name(i)
            columns.append(a)
            widths.append(self.get_length(df[df.columns[i]])) 
        
        for c,w in zip(columns,widths):
            worksheet.set_column(c, w)
        
        worksheet.conditional_format(contentrange,{'type':'no_errors',
                                                   'format':column_format})
        worksheet.conditional_format(headerrange,{'type':'no_errors',
                                                  'format':header_format})
        worksheet.conditional_format(tablerange,{'type':'text',
                                                 'criteria':'containing',
                                                 'value':'Click link',
                                                 'format':link_format})
           
        #Formatting for putting in the header titles
        table_headers = [{'header':c} for c in  df.columns]
        #Create a table with the data
        worksheet.add_table(tablerange,{'columns' : table_headers})         
        
        writer.save()
        return

# %%
clean_df = clean_up(df)

# %%
#Get the target organization list
org_list = txt_reader('orgs')

# %%
org_df = filter_prioritize(clean_df,org_list,'공고기관')

# %%
go_to_excel = create_excel()

# %%
go_to_excel.to_excel(clean_df,'full')
# Out:
# saving the full list...

# %%
go_to_excel.to_excel(org_df,'orgs')
# Out:
# saving the orgs list...

# %%
print ('All done! Please hit Enter to exit this command prompt. ')
input()
# Out:
# All done! Please hit Enter to exit this command prompt.
# ''
